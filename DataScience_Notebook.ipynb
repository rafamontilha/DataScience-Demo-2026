# %% [markdown]
# <a href="https://colab.research.google.com/github/rafamontilha/DataScience-Demo-2026/blob/main/DataScience_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %% [markdown]
# ##EDA

# %% [markdown]
# ##Modeling

# %% [markdown]
# ### Classification Algorithm A

# %% [markdown]
# ##Conclusion
