# %% [markdown]
# <a href="https://colab.research.google.com/github/rafamontilha/DataScience-Demo-2026/blob/main/Chapter7_data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 7:  Data Science

# %% [markdown]
# **This is a chapter in the book Minimal Python**
#
# * [Buy a copy on LeanPub](https://leanpub.com/minimalpython)
# * [Buy a copy from Amazon](https://www.amazon.com/Minimal-Python-efficient-programmer-onemillion2021-ebook/dp/B0855NSRR7)
#
# [*Licensed Under Attribution-NonCommercial-ShareAlike 4.0*](https://creativecommons.org/licenses/by-nc-sa/4.0/)
#
# ![Minimal Python Book](https://d2sofvawe08yqg.cloudfront.net/minimalpython/hero?1582640276)

# %% [markdown]
# ## Ingest

# %% [markdown]
# *COVID-19 Data from [New York Times Github](https://github.com/nytimes/covid-19-data)*

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv")
df.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %% [markdown]
# Last five rows

# %%
df.tail()
# Out:
#              date          state  fips    cases  deaths
# 61937  2023-03-23       Virginia    51  2298300   23782
# 61938  2023-03-23     Washington    53  1940704   15905
# 61939  2023-03-23  West Virginia    54   645710    8132
# 61940  2023-03-23      Wisconsin    55  2014524   16485
# 61941  2023-03-23        Wyoming    56   185800    2014

# %% [markdown]
# *What are the columns?*

# %%
df.columns
# Out:
# Index(['date', 'state', 'fips', 'cases', 'deaths'], dtype='object')

# %% [markdown]
# *What is the shape:  i.e. rows,columns?*

# %%
df.shape
# Out:
# (61942, 5)

# %% [markdown]
# ## EDA

# %% [markdown]
# *What are general characteristics of the data?  A good way to find out is `df.describe`*

# %%
df.describe()
# Out:
#                fips         cases         deaths
# count  61942.000000  6.194200e+04   61942.000000
# mean      32.247958  8.898301e+05   11779.067499
# std       18.788383  1.470231e+06   17345.774849
# min        1.000000  1.000000e+00       0.000000
# 25%       17.000000  7.078350e+04    1171.000000
# 50%       31.000000  3.514960e+05    5035.000000
# 75%       46.000000  1.043231e+06   14912.000000
# max       78.000000  1.216916e+07  104277.000000

# %% [markdown]
# *Cases and Deaths in the USA due to Covid-19*

# %%
import seaborn as sns
sns.scatterplot(x="cases", y="deaths",
                hue="deaths",size="deaths", data=df)
# Out:
# <Axes: xlabel='cases', ylabel='deaths'>

# %% [markdown]
# ### Date-based EDA

# %% [markdown]
# *Dealing with dates by setting index*

# %%
df = pd.read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv")
df["date"] = pd.to_datetime(df["date"])
df = df.set_index("date")
print(f"Columns: {df.columns}")
df.index
# Out:
# Columns: Index(['state', 'fips', 'cases', 'deaths'], dtype='object')
# DatetimeIndex(['2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-24', '2020-01-25', '2020-01-25', '2020-01-25',
#                '2020-01-26', '2020-01-26',
#                ...
#                '2023-03-23', '2023-03-23', '2023-03-23', '2023-03-23',
#                '2023-03-23', '2023-03-23', '2023-03-23', '2023-03-23',
#                '2023-03-23', '2023-03-23'],
#               dtype='datetime64[ns]', name='date', length=61942, freq=None)

# %% [markdown]
# *Filter results by date range*

# %%
unique_dates = df.index.unique().sort_values()
today = unique_dates[-1].date()
daybefore = unique_dates[-2].date()

print(f"Today {today}")
print(f"Two days ago {daybefore}")
# Out:
# Today 2023-03-23
# Two days ago 2023-03-22

# %%
df.loc[daybefore:today].head()
# Out:
#                      state  fips    cases  deaths
# date
# 2023-03-22         Alabama     1  1648385   21631
# 2023-03-22          Alaska     2   308893    1438
# 2023-03-22  American Samoa    60     8320      34
# 2023-03-22         Arizona     4  2451062   33190
# 2023-03-22        Arkansas     5  1008303   13068

# %% [markdown]
# *The distribution of the data by date*

# %%
sns.kdeplot(df.loc[daybefore:today].groupby(level=0)["deaths"].sum(), fill=True)
# Out:
# <Axes: xlabel='deaths', ylabel='Density'>

# %% [markdown]
# *Sort DataFrame in place by states with highest deaths and cases and show first 10 results*

# %%
current_df = df.loc[daybefore:today].sort_values(by=["deaths", "cases"], ascending=False)
current_df.head(10)
# Out:
#                    state  fips     cases  deaths
# date
# 2023-03-23    California     6  12169158  104277
# 2023-03-22    California     6  12155467  104196
# 2023-03-23         Texas    48   8447168   94518
# 2023-03-22         Texas    48   8447168   94515
# 2023-03-22       Florida    12   7542869   87141
# 2023-03-23       Florida    12   7542869   87141
# 2023-03-22      New York    36   6803974   80138
# 2023-03-23      New York    36   6805271   80109
# 2023-03-22  Pennsylvania    42   3539135   50701
# 2023-03-23  Pennsylvania    42   3539135   50701

# %% [markdown]
# *There should be 50 states and District of Columbia*

# %%
current_df.shape
# Out:
# (112, 4)

# %% [markdown]
# ### State Based Analysis

# %% [markdown]
# *Get 10 states and subset*

# %%
top_ten_states = list(current_df["state"].head(10).values)
top_ten_states
# Out:
# ['California',
#  'California',
#  'Texas',
#  'Texas',
#  'Florida',
#  'Florida',
#  'New York',
#  'New York',
#  'Pennsylvania',
#  'Pennsylvania']

# %%
top_states_df = df[df['state'].isin(top_ten_states)].drop(columns="fips")

# %% [markdown]
# *Verify the unique states left is the same 10*

# %%
set(top_states_df.state.values)
# Out:
# {'California', 'Florida', 'New York', 'Pennsylvania', 'Texas'}

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
ax = sns.lmplot(x="cases", y="deaths",
                    height=3.5,
                    col="state",
                    col_wrap=5,
                    hue="state",
                    palette="Set2",
                    data=top_states_df)
ax.fig.subplots_adjust(wspace=.2)

# %% [markdown]
# *Interactive plot of top states*

# %%
top_states_march_current_df = top_states_df.loc["2020-03-08":today].sort_values(by=["deaths", "cases"], ascending=True)
top_states_march_current_df.head()
# Out:
#                    state  cases  deaths
# date
# 2020-03-08  Pennsylvania      6       0
# 2020-03-09  Pennsylvania     10       0
# 2020-03-10  Pennsylvania     12       0
# 2020-03-11  Pennsylvania     16       0
# 2020-03-12  Pennsylvania     22       0

# %%
import plotly.io as pio
pio.renderers.default = 'colab'
import plotly.express as px
fig = px.scatter(top_states_march_current_df, x=top_states_march_current_df.index, y="cases", size="deaths", color="state", facet_col="state")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ca2359f0-68d6-4616-8ae2-ab0d1714a23f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca2359f0-68d6-4616-8ae2-ab0d1714a23f")) {                    Plotly.newPlot(                        "ca2359f0-68d6-4616-8ae2-ab0d1714a23f",                        [{"hovertemplate":"state=Pennsylvania\u003cbr\u003edate=%{x}\u003cbr\u003ecases=%{y}\u003cbr\u003edeaths=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"
# %% [markdown]
# ### Search for Features:  Political, Health and Finance

# %% [markdown]
# *Sugar Intake By State*

# %%
cdc_2013 = pd.read_csv("https://raw.githubusercontent.com/noahgift/sugar/master/data/education_sugar_cdc_2003.csv")
cdc_2013.set_index("State", inplace=True)
for column in cdc_2013.columns:
  # Convert to string, then remove content in parentheses and strip whitespace
  cdc_2013[column]=cdc_2013[column].astype(str).str.replace(r'\s*\(.*?\)', '', regex=True).str.strip()
  cdc_2013[column]=pd.to_numeric(cdc_2013[column])

cdc_2013.reset_index(inplace=True)
cdc_2013.rename(columns={"State": "state", "Employed": "employed-sugar-intake-daily"},inplace=True)
cdc_2013.head()
# Out:
#                   state  employed-sugar-intake-daily  Not employed  Retired  \
# 0                Alaska                         26.2          32.1     16.0
# 1               Arizona                         33.0          28.7     13.8
# 2            California                         22.9          30.2     15.0
# 3           Connecticut                         18.9          24.3     15.0
# 4  District of Columbia                         18.5          34.6     18.5
#
#    <High school  High school  Some college  College graduate
# 0          47.1         34.9          24.2              12.9
# 1          40.4         36.5          24.4              14.6
# 2          38.5         29.9          21.4              11.5
# 3          27.8         26.9          19.9              10.2
# 4          45.6         39.0          28.9               8.4

# %% [markdown]
# *Combine Sugar Data and Covid-19 Data*

# %%
cdc_employed_df = cdc_2013[["employed-sugar-intake-daily", "state"]]
sugar_covid_df = df.merge(cdc_employed_df, how="inner", on="state")
sugar_covid_df.head()
# Out:
#         state  fips  cases  deaths  employed-sugar-intake-daily
# 0  California     6      1       0                         22.9
# 1     Arizona     4      1       0                         33.0
# 2  California     6      2       0                         22.9
# 3     Arizona     4      1       0                         33.0
# 4  California     6      2       0                         22.9

# %% [markdown]
# *What about data from the 2016 Election?*

# %%
election_df = pd.read_csv("https://raw.githubusercontent.com/paiml/minimal-python/master/data/2016-Electoral-Votes.csv")
election_df.rename(columns={"State": "state"},inplace=True)
election_df.drop(columns="Votes", inplace=True)
election_df = pd.concat([election_df, pd.get_dummies(election_df["Winning Party"])], axis=1);
election_df.head()
#election_df["Republican?"] = pd.get_dummies(election_df, columns=["Winning Party"])
#election_df.head()
# Out:
#         state Winning Party  Democrats  Republicans
# 0     Alabama   Republicans      False         True
# 1      Alaska   Republicans      False         True
# 2     Arizona   Republicans      False         True
# 3    Arkansas   Republicans      False         True
# 4  California     Democrats       True        False

# %%
sugar_covid_df = sugar_covid_df.merge(election_df, how="inner", on="state")
sugar_covid_df.head()
# Out:
#         state  fips  cases  deaths  employed-sugar-intake-daily  \
# 0  California     6      1       0                         22.9
# 1     Arizona     4      1       0                         33.0
# 2  California     6      2       0                         22.9
# 3     Arizona     4      1       0                         33.0
# 4  California     6      2       0                         22.9
#
#   Winning Party_x  Democrats_x  Republicans_x Winning Party_y  Democrats_y  \
# 0       Democrats         True          False       Democrats         True
# 1     Republicans        False           True     Republicans        False
# 2       Democrats         True          False       Democrats         True
# 3     Republicans        False           True     Republicans        False
# 4       Democrats         True          False       Democrats         True
#
#    Republicans_y
# 0          False
# 1           True
# 2          False
# 3           True
# 4          False

# %% [markdown]
# *Generate Heatmap*

# %%
numeric_df = sugar_covid_df.select_dtypes(include=['number', 'bool'])
numeric_df.corr()
# Out:
#                                  fips     cases    deaths  \
# fips                         1.000000 -0.120943 -0.127549
# cases                       -0.120943  1.000000  0.935557
# deaths                      -0.127549  0.935557  1.000000
# employed-sugar-intake-daily  0.269999 -0.124204 -0.161596
# Democrats_x                 -0.187330  0.221498  0.299948
# Republicans_x                0.187330 -0.221498 -0.299948
# Democrats_y                 -0.187330  0.221498  0.299948
# Republicans_y                0.187330 -0.221498 -0.299948
#
#                              employed-sugar-intake-daily  Democrats_x  \
# fips                                            0.269999    -0.187330
# cases                                          -0.124204     0.221498
# deaths                                         -0.161596     0.299948
# employed-sugar-intake-daily                     1.000000    -0.767539
# Democrats_x                                    -0.767539     1.000000
# Republicans_x                                   0.767539    -1.000000
# Democrats_y                                    -0.767539     1.000000
# Republicans_y                                   0.767539    -1.000000
#
#                              Republicans_x  Democrats_y  Republicans_y
# fips                              0.187330    -0.187330       0.187330
# cases                            -0.221498     0.221498      -0.221498
# deaths                           -0.299948     0.299948      -0.299948
# employed-sugar-intake-daily       0.767539    -0.767539       0.767539
# Democrats_x                      -1.000000     1.000000      -1.000000
# Republicans_x                     1.000000    -1.000000       1.000000
# Democrats_y                      -1.000000     1.000000      -1.000000
# Republicans_y                     1.000000    -1.000000       1.000000

# %%
import plotly.graph_objects as go

fig = go.Figure(data=go.Heatmap(
                   z=numeric_df.corr(),
                   x=['fips','cases', 'deaths', 'employed-sugar-intake-daily', 'Democrats_x', 'Republicans_x', 'Democrats_y', 'Republicans_y'],
                   y=['fips','cases', 'deaths', 'employed-sugar-intake-daily', 'Democrats_x', 'Republicans_x', 'Democrats_y', 'Republicans_y'],
                   hoverongaps = False))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1e933457-1447-4906-8e34-0b7b60d7f239" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e933457-1447-4906-8e34-0b7b60d7f239")) {                    Plotly.newPlot(                        "1e933457-1447-4906-8e34-0b7b60d7f239",                        [{"hoverongaps":false,"x":["fips","cases","deaths","employed-sugar-intake-daily","Democrats_x","Republicans_x","Democrats_y","Republicans_y"],"y":["fips","cases","deaths","employed-sugar-intake-daily","Democrats_x","Republicans_x","Democrats_y","Republicans_y"],"z":[[1.0,-0.12094338336123187,-0.12754895813800243,0.2699991675624438,-0.18733019151334507,0.1873301915133446,-0.18733019151334507,0.1873301915133446],[-0.12094338336123187,1.0,0.9355565606297334,-0.12420411690113209,0.22149847534115966,-0.22149847534116246,0.22149847534115966,-0.22149847534116246],[-0.12754895813800243,0.9355565606297334,1.0,-0.16159588413525441,0.29994788288596663,-0.29994788288596924,0.29994788288596663,-0.29994788288596924],[0.2699991675624438,-0.12420411690113209,-0.16159588413525441,1.0,-0.7675387319367714,0.7675387319367726,-0.7675387319367714,0.7675387319367726],[-0.18733019151334507,0.22149847534115966,0.29994788288596663,-0.7675387319367714,1.0,-1.0000000000000002,1.0,-1.0000000000000002],[0.1873301915133446,-0.22149847534116246,-0.29994788288596924,0.7675387319367726,-1.0000000000000002,1.0,-1.0000000000000002,1.0],[-0.18733019151334507,0.22149847534115966,0.29994788288596663,-0.7675387319367714,1.0,-1.0000000000000002,1.0,-1.0000000000000002],[0.1873301915133446,-0.22149847534116246,-0.29994788288596924,0.7675387319367726,-1.0000000000000002,1.0,-1.0000000000000002,1.0]],"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888 ...

# %%
sugar_covid_df.to_csv("covid-eda.csv")

# %% [markdown]
# *What about Real-Estate Data?*

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## Conclusion
